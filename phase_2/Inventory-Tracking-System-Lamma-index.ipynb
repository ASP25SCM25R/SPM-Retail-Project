# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from dotenv import load_dotenv
import os

# Load environment variables
load_dotenv()
api_key = os.environ.get("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY not set.")

# Load PDF documents
documents = SimpleDirectoryReader(input_files=["retail.pdf"]).load_data()

# Create a vector index for querying
index = VectorStoreIndex.from_documents(documents)

# Create a query engine
query_engine = index.as_query_engine()

# Extract requirements from the PDF
response = query_engine.query("Summarize the key requirements for the Retail Inventory Management System.")
customer_requirements = response.response
print("Extracted Requirements:", customer_requirements)
# Out:
# Extracted Requirements: The key requirements for the Retail Inventory Management System include tracking inventory levels accurately, managing stock across multiple locations, integrating with point-of-sale systems, providing real-time updates on stock availability, generating reports for sales analysis, and supporting barcode scanning for efficient inventory management.

# %%
# Initialize LLM for LangChain
llm = ChatOpenAI(model="gpt-4o-mini", api_key=api_key)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage

# Initialize the LLM
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, api_key=api_key)

# Agent Prompts
CUSTOMER_PROMPT = """You are a Customer Agent for a retail business. Your role is to provide clear requirements for the Retail Inventory Management System based on provided details. Relay these to the Product Owner and review sprint deliverables, providing feedback for improvements. Requirements: {requirements}"""

PRODUCT_OWNER_PROMPT = """You are a Product Owner in a Scrum team. Translate customer requirements into a product backlog with prioritized user stories. Collaborate with the Scrum Master to define sprint goals and incorporate customer feedback after each sprint. Deliverables: product backlog, sprint goals."""

SCRUM_MASTER_PROMPT = """You are a Scrum Master facilitating Agile ceremonies. Create sprint backlogs based on the product backlog, ensure team collaboration, and remove blockers. Deliverables: sprint backlog, sprint summary."""

DEVELOPER_PROMPT = """You are a Developer Agent. Implement features from the sprint backlog, writing modular code for the Retail Inventory Management System. Deliverables: feature implementations, progress report."""

QA_ENGINEER_PROMPT = """You are a QA Engineer Agent. Develop and execute test cases for sprint deliverables, ensuring functionality and quality. Deliverables: test cases, test results, defect report."""

UI_UX_DESIGNER_PROMPT = """You are a UI/UX Designer Agent. Create wireframes and designs for the sprint's user stories, ensuring usability and accessibility. Deliverables: wireframes, design prototypes."""

BUSINESS_ANALYST_PROMPT = """You are a Business Analyst Agent. Refine user stories with detailed requirements and acceptance criteria. Deliverables: refined user stories, requirements document."""

DEVOPS_ENGINEER_PROMPT = """You are a DevOps Engineer Agent. Set up CI/CD pipelines and deploy sprint deliverables. Deliverables: deployment plan, pipeline configuration."""

ARCHITECT_PROMPT = """You are an Architect Agent. Design the system architecture for sprint features, ensuring scalability. Deliverables: architecture diagram, technical specifications."""

SECURITY_ENGINEER_PROMPT = """You are a Security Engineer Agent. Audit sprint deliverables for vulnerabilities and recommend mitigations. Deliverables: security report, mitigation plan."""

TECHNICAL_WRITER_PROMPT = """You are a Technical Writer Agent. Document sprint deliverables, including user guides and release notes. Deliverables: documentation, release summary and provide a final report after three sprints."""

# %%
from typing import TypedDict, List, Dict, Optional

class ScrumState(TypedDict):
    customer_requirements: str
    product_backlog: str
    sprint_backlog: str
    sprint_number: int
    sprint_deliverables: Dict[str, str]
    customer_feedback: str
    current_phase: str
    conversation_history: List[Dict[str, str]]
    completion_status: str

# %%
def customer_phase(state: ScrumState) -> ScrumState:
    messages = [
        SystemMessage(content=CUSTOMER_PROMPT.format(requirements=state["customer_requirements"])),
        HumanMessage(content="Provide the requirements for the Retail Inventory Management System.")
    ]
    response = llm.invoke(messages)
    state["customer_requirements"] = response.content
    state["conversation_history"].append({"Customer": response.content})
    state["current_phase"] = "product_owner"
    print("Customer Requirements:", response.content)
    return state

def product_owner_phase(state: ScrumState) -> ScrumState:
    messages = [
        SystemMessage(content=PRODUCT_OWNER_PROMPT),
        HumanMessage(content=f"Create a product backlog based on these requirements:\n{state['customer_requirements']}")
    ]
    response = llm.invoke(messages)
    state["product_backlog"] = response.content
    state["conversation_history"].append({"Product Owner": response.content})
    state["current_phase"] = "scrum_master"
    print("Product Backlog:", response.content)
    return state

def scrum_master_phase(state: ScrumState) -> ScrumState:
    messages = [
        SystemMessage(content=SCRUM_MASTER_PROMPT),
        HumanMessage(content=f"Create a sprint backlog for sprint {state['sprint_number']} based on this product backlog:\n{state['product_backlog']}")
    ]
    response = llm.invoke(messages)
    state["sprint_backlog"] = response.content
    state["conversation_history"].append({"Scrum Master": response.content})
    state["current_phase"] = "development"
    print(f"Sprint {state['sprint_number']} Backlog:", response.content)
    return state

def development_phase(state: ScrumState) -> ScrumState:
    team_agents = [
        ("Developer", DEVELOPER_PROMPT),
        ("QA Engineer", QA_ENGINEER_PROMPT),
        ("UI/UX Designer", UI_UX_DESIGNER_PROMPT),
        ("Business Analyst", BUSINESS_ANALYST_PROMPT),
        ("DevOps Engineer", DEVOPS_ENGINEER_PROMPT),
        ("Architect", ARCHITECT_PROMPT),
        ("Security Engineer", SECURITY_ENGINEER_PROMPT),
        ("Technical Writer", TECHNICAL_WRITER_PROMPT)
    ]
    state["sprint_deliverables"] = {}
    for agent_name, prompt in team_agents:
        messages = [
            SystemMessage(content=prompt),
            HumanMessage(content=f"Perform your role for sprint {state['sprint_number']} based on this sprint backlog:\n{state['sprint_backlog']}")
        ]
        response = llm.invoke(messages)
        state["sprint_deliverables"][agent_name] = response.content
        state["conversation_history"].append({agent_name: response.content})
        print(f"{agent_name} Deliverables:", response.content)
    state["current_phase"] = "customer_review"
    return state

def customer_review_phase(state: ScrumState) -> ScrumState:
    deliverables_summary = "\n".join([f"{agent}: {content}" for agent, content in state["sprint_deliverables"].items()])
    messages = [
        SystemMessage(content=CUSTOMER_PROMPT.format(requirements=state["customer_requirements"])),
        HumanMessage(content=f"Review the deliverables for sprint {state['sprint_number']}:\n{deliverables_summary}\nProvide feedback.")
    ]
    response = llm.invoke(messages)
    state["customer_feedback"] = response.content
    state["conversation_history"].append({"Customer Feedback": response.content})
    state["sprint_number"] += 1
    state["current_phase"] = "product_owner" if state["sprint_number"] <= 3 else "completed"
    print(f"Customer Feedback (Sprint {state['sprint_number']-1}):", response.content)
    return state

def final_report_phase(state: ScrumState) -> ScrumState:
    history_summary = "\n".join([f"{key}: {value}" for entry in state["conversation_history"] for key, value in entry.items()])
    messages = [
        SystemMessage(content=TECHNICAL_WRITER_PROMPT.format(sprint_number="final")),
        HumanMessage(content=f"Generate a final report summarizing the three sprints based on this history:\n{history_summary}")
    ]
    response = llm.invoke(messages)
    print("\n=== Final Report for Three Sprints ===")
    print(response.content)
    state["conversation_history"].append({"Technical Writer Final Report": response.content})
    return state

# %%
def run_workflow():
    # Initialize state
    initial_state = ScrumState(
        customer_requirements=customer_requirements,  # From LlamaIndex
        product_backlog="",
        sprint_backlog="",
        sprint_number=1,
        sprint_deliverables={},
        customer_feedback="",
        current_phase="customer",
        conversation_history=[],
        completion_status="in_progress"
    )

    state = initial_state
    while state["completion_status"] != "completed":
        if state["current_phase"] == "customer":
            state = customer_phase(state)
        elif state["current_phase"] == "product_owner":
            state = product_owner_phase(state)
        elif state["current_phase"] == "scrum_master":
            state = scrum_master_phase(state)
        elif state["current_phase"] == "development":
            state = development_phase(state)
        elif state["current_phase"] == "customer_review":
            state = customer_review_phase(state)
        elif state["current_phase"] == "final_report":
            state = final_report_phase(state)
            state["completion_status"] = "completed"
            #break

    print("Workflow completed after 3 sprints!")
    return state

# Run the workflow
final_state = run_workflow()
# Out:
# Customer Requirements: Here are the key requirements for the Retail Inventory Management System:
#
# 1. **Inventory Tracking**:
#    - The system must accurately track inventory levels in real-time across all locations.
#    - It should provide alerts for low stock levels to prevent stockouts.
#
# 2. **Multi-location Management**:
#    - The system must support inventory management across multiple retail locations.
#    - Users should be able to view and manage stock levels for each location individually.
#
# 3. **Point-of-Sale Integration**:
#    - The system must integrate seamlessly with existing point-of-sale (POS) systems to ensure accurate sales data is reflected in inventory levels.
#    - It should automatically update inventory counts based on sales transactions.
#
# 4. **Real-time Stock Updates**:
#    - The system must provide real-time updates on stock availability to ensure that customers and staff have access to the most current inventory information.
#
# 5. **Reporting and Analytics**:
#    - The system should generate comprehensive reports for sales analysis, including sales trends, inventory turnover rates, and stock performance.
#    - Users should be able to customize reports based on various parameters (e.g., date range, product category).
#
# 6. **Barcode Scanning Support**:
#    - The system must support barcode scanning for efficient inventory management, including receiving, tracking, and selling products.
#    - It should allow for easy addition and removal of items from inventory using barcode technology.
#
# 7. **User Access and Permissions**:
#    - The system should have user access controls to ensure that only authorized personnel can make changes to inventory levels and settings.
#    - Different roles (e.g., manager, staff) should have varying levels of access based on their responsibilities.
#
# 8. **User-Friendly Interface**:
#    - The system must have an intuitive and user-friendly interface to facilitate ease of use for all staff members.
#    - Training materials and support should be available to assist users in navigating the system.
#
# 9. **Data Backup and Security**:
#    - The system must include data backup solutions to prevent loss of inventory data.
#    - It should implement security measures to protect sensitive information and ensure compliance with data protection regulations.
#
# 10. **Scalability**:
#     - The system should be scalable to accommodate future growth, including the addition of new locations or increased inventory levels.
#
# These requirements will help ensure that the Retail Inventory Management System meets the needs of the business and enhances overall inventory management efficiency.
# Product Backlog: Based on the provided requirements for the Retail Inventory Management System, here is a prioritized product backlog with user stories:
#
# ### Product Backlog
#
# 1. **User Story: Inventory Tracking**
#    - As a store manager, I want to track inventory levels in real-time across all locations so that I can manage stock effectively.
#    - Acceptance Criteria:
#      - The system displays current inventory levels for each product.
#      - Alerts are generated for low stock levels.
#
# 2. **User Story: Multi-location Management**
#    - As a regional manager, I want to manage inventory across multiple retail locations so that I can optimize stock distribution.
#    - Acceptance Criteria:
#      - Users can view stock levels for each location individually.
#      - Users can transfer stock between locations.
#
# 3. **User Story: Point-of-Sale Integration**
#    - As a cashier, I want the system to integrate with our existing POS system so that sales data is automatically reflected in inventory levels.
#    - Acceptance Criteria:
#      - Inventory counts are updated automatically after each sale.
#      - Sales data is accurately reflected in inventory reports.
#
# 4. **User Story: Real-time Stock Updates**
#    - As a customer, I want to see real-time stock availability so that I can make informed purchasing decisions.
#    - Acceptance Criteria:
#      - Stock availability is updated in real-time on the customer-facing interface.
#      - Staff can access real-time inventory data on their devices.
#
# 5. **User Story: Reporting and Analytics**
#    - As a business analyst, I want to generate comprehensive reports for sales analysis so that I can identify trends and make data-driven decisions.
#    - Acceptance Criteria:
#      - Users can generate reports based on sales trends, inventory turnover rates, and stock performance.
#      - Reports can be customized by date range and product category.
#
# 6. **User Story: Barcode Scanning Support**
#    - As a warehouse staff member, I want to use barcode scanning for inventory management so that I can efficiently receive, track, and sell products.
#    - Acceptance Criteria:
#      - The system supports barcode scanning for adding and removing items from inventory.
#      - Scanning updates inventory levels in real-time.
#
# 7. **User Story: User Access and Permissions**
#    - As an IT administrator, I want to set user access controls so that only authorized personnel can make changes to inventory levels.
#    - Acceptance Criteria:
#      - Different roles (manager, staff) have varying levels of access.
#      - Unauthorized access attempts are logged.
#
# 8. **User Story: User-Friendly Interface**
#    - As a new staff member, I want an intuitive interface so that I can easily navigate the system without extensive training.
#    - Acceptance Criteria:
#      - The interface is designed for ease of use.
#      - Training materials and support resources are available.
#
# 9. **User Story: Data Backup and Security**
#    - As a compliance officer, I want the system to include data backup solutions so that we can prevent loss of inventory data.
#    - Acceptance Criteria:
#      - Regular backups are scheduled and can be restored easily.
#      - Security measures are in place to protect sensitive information.
#
# 10. **User Story: Scalability**
#     - As a business owner, I want the system to be scalable so that it can accommodate future growth and additional locations.
#     - Acceptance Criteria:
#       - The system can handle increased inventory levels without performance degradation.
#       - New locations can be added without significant reconfiguration.
#
# ### Sprint Goals
#
# **Sprint 1 Goal**: Implement core inventory tracking and multi-location management features to allow real-time inventory visibility and management across locations.
#
# **Sprint 2 Goal**: Integrate the system with existing POS systems and implement real-time stock updates to ensure accurate inventory counts post-sales.
#
# **Sprint 3 Goal**: Develop reporting and analytics capabilities, including customizable reports for sales analysis and inventory performance.
#
# **Sprint 4 Goal**: Implement barcode scanning support and user access controls to enhance inventory management efficiency and security.
#
# **Sprint 5 Goal**: Focus on user interface improvements, data backup solutions, and security measures to ensure a user-friendly experience and data protection.
#
# **Sprint 6 Goal**: Ensure system scalability and performance optimization to accommodate future growth and additional retail locations.
#
# This structured approach will help the Scrum team deliver a robust Retail Inventory Management System that meets customer needs and enhances overall inventory management efficiency.
# Sprint 1 Backlog: ### Sprint Backlog for Sprint 1
#
# **Sprint Duration**: 2 weeks
# **Sprint Goal**: Implement core inventory tracking and multi-location management features to allow real-time inventory visibility and management across locations.
#
# #### Selected User Stories for Sprint 1
#
# 1. **User Story: Inventory Tracking**
#    - **Tasks**:
#      - Design database schema for inventory tracking.
#      - Develop API to fetch current inventory levels.
#      - Implement front-end display for inventory levels.
#      - Create alert system for low stock levels.
#    - **Estimated Effort**: 8 story points
#
# 2. **User Story: Multi-location Management**
#    - **Tasks**:
#      - Design database schema for multi-location management.
#      - Develop API to fetch stock levels for each location.
#      - Implement front-end interface for viewing stock levels by location.
#      - Create functionality for transferring stock between locations.
#    - **Estimated Effort**: 8 story points
#
# #### Total Estimated Effort for Sprint 1: 16 story points
#
# ### Team Collaboration and Responsibilities
#
# - **Developers**:
#   - Work on the implementation of the inventory tracking and multi-location management features.
#   - Collaborate on the design of the database schema and APIs.
#
# - **QA/Testers**:
#   - Prepare test cases for inventory tracking and multi-location management.
#   - Conduct testing once features are implemented to ensure acceptance criteria are met.
#
# - **Product Owner**:
#   - Clarify requirements and acceptance criteria for user stories.
#   - Prioritize tasks and assist in removing any blockers.
#
# - **Scrum Master**:
#   - Facilitate daily stand-ups to track progress and address blockers.
#   - Ensure team collaboration and communication.
#
# ### Blockers and Risks
#
# - **Potential Blockers**:
#   - Delays in database design approval.
#   - Integration issues with existing systems (if applicable).
#
# - **Mitigation Strategies**:
#   - Schedule a design review meeting early in the sprint.
#   - Identify integration points and potential issues during sprint planning.
#
# ### Sprint Summary
#
# At the end of Sprint 1, the team aims to deliver the following:
#
# - A fully functional inventory tracking system that displays current inventory levels and generates alerts for low stock.
# - A multi-location management feature that allows users to view stock levels for each location and transfer stock between locations.
#
# The team will conduct a sprint review to demonstrate the completed features and gather feedback from stakeholders. A sprint retrospective will follow to discuss what went well, what could be improved, and how to enhance team collaboration in future sprints.
#
# This structured approach will ensure that the team remains focused on delivering value while continuously improving their processes.
# Developer Deliverables: ## Sprint 1 Progress Report
#
# ### Sprint Overview
# - **Sprint Duration**: 2 weeks
# - **Sprint Goal**: Implement core inventory tracking and multi-location management features for real-time inventory visibility and management across locations.
# - **Total Estimated Effort**: 16 story points
#
# ### Completed User Stories and Tasks
#
# #### 1. User Story: Inventory Tracking
# - **Database Schema Design**:
#   - Created a relational database schema for inventory tracking.
#   - Tables include `Products`, `Inventory`, and `Alerts`.
#
#   ```sql
#   CREATE TABLE Products (
#       id INT PRIMARY KEY AUTO_INCREMENT,
#       name VARCHAR(255) NOT NULL,
#       description TEXT,
#       price DECIMAL(10, 2) NOT NULL
#   );
#
#   CREATE TABLE Inventory (
#       id INT PRIMARY KEY AUTO_INCREMENT,
#       product_id INT,
#       location_id INT,
#       quantity INT NOT NULL,
#       FOREIGN KEY (product_id) REFERENCES Products(id)
#   );
#
#   CREATE TABLE Alerts (
#       id INT PRIMARY KEY AUTO_INCREMENT,
#       product_id INT,
#       threshold INT NOT NULL,
#       alert_message VARCHAR(255),
#       FOREIGN KEY (product_id) REFERENCES Products(id)
#   );
#   ```
#
# - **API Development**:
#   - Developed RESTful API endpoints to fetch current inventory levels.
#
#   ```python
#   from flask import Flask, jsonify
#   from models import Inventory  # Assuming SQLAlchemy models are defined
#
#   app = Flask(__name__)
#
#   @app.route('/api/inventory', methods=['GET'])
#   def get_inventory():
#       inventory_data = Inventory.query.all()
#       return jsonify([item.to_dict() for item in inventory_data])
#   ```
#
# - **Front-end Display**:
#   - Implemented a simple front-end using React to display inventory levels.
#
#   ```javascript
#   import React, { useEffect, useState } from 'react';
#
#   const InventoryDisplay = () => {
#       const [inventory, setInventory] = useState([]);
#
#       useEffect(() => {
#           fetch('/api/inventory')
#               .then(response => response.json())
#               .then(data => setInventory(data));
#       }, []);
#
#       return (
#           <div>
#               <h1>Inventory Levels</h1>
#               <ul>
#                   {inventory.map(item => (
#                       <li key={item.id}>{item.name}: {item.quantity}</li>
#                   ))}
#               </ul>
#           </div>
#       );
#   };
#
#   export default InventoryDisplay;
#   ```
#
# - **Alert System**:
#   - Created a basic alert system for low stock levels.
#
#   ```python
#   def check_low_stock():
#       low_stock_items = Inventory.query.filter(Inventory.quantity < Alerts.threshold).all()
#       for item in low_stock_items:
#           send_alert(item)  # Placeholder for alert sending logic
#   ```
#
# #### 2. User Story: Multi-location Management
# - **Database Schema Design**:
#   - Extended the schema to include `Locations`.
#
#   ```sql
#   CREATE TABLE Locations (
#       id INT PRIMARY KEY AUTO_INCREMENT,
#       name VARCHAR(255) NOT NULL,
#       address VARCHAR(255)
#   );
#   ```
#
# - **API Development**:
#   - Developed API to fetch stock levels for each location.
#
#   ```python
#   @app.route('/api/inventory/location/<int:location_id>', methods=['GET'])
#   def get_inventory_by_location(location_id):
#       inventory_data = Inventory.query.filter_by(location_id=location_id).all()
#       return jsonify([item.to_dict() for item in inventory_data])
#   ```
#
# - **Front-end Interface**:
#   - Implemented a front-end interface for viewing stock levels by location.
#
#   ```javascript
#   const LocationInventoryDisplay = ({ locationId }) => {
#       const [inventory, setInventory] = useState([]);
#
#       useEffect(() => {
#           fetch(`/api/inventory/location/${locationId}`)
#               .then(response => response.json())
#               .then(data => setInventory(data));
#       }, [locationId]);
#
#       return (
#           <div>
#               <h1>Inventory Levels for Location {locationId}</h1>
#               <ul>
#                   {inventory.map(item => (
#                       <li key={item.id}>{item.name}: {item.quantity}</li>
#                   ))}
#               </ul>
#           </div>
#       );
#   };
#   ```
#
# - **Stock Transfer Functionality**:
#   - Created functionality for transferring stock between locations.
#
#   ```python
#   @app.route('/api/transfer', methods=['POST'])
#   def transfer_stock():
#       data = request.json
#       # Logic to transfer stock between locations
#       # Update Inventory table accordingly
#       return jsonify({"message": "Transfer successful"}), 200
#   ```
#
# ### Summary of Completed Features
# - Fully functional inventory tracking system with real-time visibility.
# - Multi-location management feature allowing users to view and manage stock levels across different locations.
# - Basic alert system for low stock levels.
#
# ### Next Steps
# - Conduct testing of the implemented features.
# - Prepare for the sprint review to demonstrate completed features.
# - Gather feedback from stakeholders for further improvements.
#
# ### Blockers and Risks
# - No significant blockers encountered during the sprint.
# - Continuous integration testing will be essential to ensure smooth functionality.
#
# ### Conclusion
# Sprint 1 has successfully delivered the core features of the Retail Inventory Management System, setting a solid foundation for future enhancements. The team will focus on refining these features based on feedback and preparing for the next sprint.
# QA Engineer Deliverables: ### Test Case Development for Sprint 1
#
# Based on the sprint backlog and user stories, I will develop test cases for the core features: Inventory Tracking and Multi-location Management. Each test case will include the test case ID, description, preconditions, steps, expected results, and actual results.
#
# #### Test Cases for User Story: Inventory Tracking
#
# **Test Case 1: Verify Database Schema for Inventory Tracking**
# - **Test Case ID**: TC_INV_001
# - **Description**: Validate the database schema for inventory tracking.
# - **Preconditions**: Database schema is designed and accessible.
# - **Steps**:
#   1. Access the database.
#   2. Check the tables and fields related to inventory tracking.
# - **Expected Result**: The database schema should include tables for inventory items, stock levels, and alerts.
#
# **Test Case 2: Fetch Current Inventory Levels API**
# - **Test Case ID**: TC_INV_002
# - **Description**: Test the API to fetch current inventory levels.
# - **Preconditions**: API is developed and accessible.
# - **Steps**:
#   1. Send a GET request to the inventory levels API endpoint.
#   2. Check the response status code.
#   3. Validate the response body for correct inventory data.
# - **Expected Result**: The API should return a 200 status code and a JSON object with current inventory levels.
#
# **Test Case 3: Front-end Display for Inventory Levels**
# - **Test Case ID**: TC_INV_003
# - **Description**: Verify the front-end display of inventory levels.
# - **Preconditions**: Front-end is implemented and connected to the API.
# - **Steps**:
#   1. Navigate to the inventory levels page.
#   2. Check if the inventory levels are displayed correctly.
# - **Expected Result**: The inventory levels should be displayed accurately as per the API response.
#
# **Test Case 4: Low Stock Alert System**
# - **Test Case ID**: TC_INV_004
# - **Description**: Test the alert system for low stock levels.
# - **Preconditions**: Low stock threshold is set in the system.
# - **Steps**:
#   1. Simulate a low stock condition for an inventory item.
#   2. Check if the alert is triggered.
# - **Expected Result**: An alert should be generated for the low stock item.
#
# #### Test Cases for User Story: Multi-location Management
#
# **Test Case 5: Verify Database Schema for Multi-location Management**
# - **Test Case ID**: TC_LOC_001
# - **Description**: Validate the database schema for multi-location management.
# - **Preconditions**: Database schema is designed and accessible.
# - **Steps**:
#   1. Access the database.
#   2. Check the tables and fields related to multi-location management.
# - **Expected Result**: The database schema should include tables for locations and stock levels per location.
#
# **Test Case 6: Fetch Stock Levels for Each Location API**
# - **Test Case ID**: TC_LOC_002
# - **Description**: Test the API to fetch stock levels for each location.
# - **Preconditions**: API is developed and accessible.
# - **Steps**:
#   1. Send a GET request to the stock levels by location API endpoint.
#   2. Check the response status code.
#   3. Validate the response body for correct stock data per location.
# - **Expected Result**: The API should return a 200 status code and a JSON object with stock levels for each location.
#
# **Test Case 7: Front-end Interface for Viewing Stock Levels by Location**
# - **Test Case ID**: TC_LOC_003
# - **Description**: Verify the front-end interface for viewing stock levels by location.
# - **Preconditions**: Front-end is implemented and connected to the API.
# - **Steps**:
#   1. Navigate to the multi-location management page.
#   2. Check if stock levels for each location are displayed correctly.
# - **Expected Result**: The stock levels should be displayed accurately as per the API response.
#
# **Test Case 8: Transfer Stock Between Locations Functionality**
# - **Test Case ID**: TC_LOC_004
# - **Description**: Test the functionality for transferring stock between locations.
# - **Preconditions**: Stock exists in the source location.
# - **Steps**:
#   1. Select an item to transfer from the source location.
#   2. Specify the target location and quantity to transfer.
#   3. Execute the transfer.
#   4. Verify stock levels in both locations.
# - **Expected Result**: The stock should be deducted from the source location and added to the target location.
#
# ### Test Execution and Reporting
#
# After the development team completes the implementation of the features, I will execute the test cases and document the results.
#
# #### Test Results Template
#
# | Test Case ID | Description | Status (Pass/Fail) | Comments |
# |---------------|-------------|---------------------|----------|
# | TC_INV_001    | Validate the database schema for inventory tracking. |  |  |
# | TC_INV_002    | Test the API to fetch current inventory levels. |  |  |
# | TC_INV_003    | Verify the front-end display of inventory levels. |  |  |
# | TC_INV_004    | Test the alert system for low stock levels. |  |  |
# | TC_LOC_001    | Validate the database schema for multi-location management. |  |  |
# | TC_LOC_002    | Test the API to fetch stock levels for each location. |  |  |
# | TC_LOC_003    | Verify the front-end interface for viewing stock levels by location. |  |  |
# | TC_LOC_004    | Test the functionality for transferring stock between locations. |  |  |
#
# ### Defect Report Template
#
# If any defects are found during testing, they will be documented in a defect report.
#
# | Defect ID | Description | Severity | Status | Comments |
# |------------|-------------|----------|--------|----------|
# |            |             |          |        |          |
#
# ### Conclusion
#
# This structured approach to testing will ensure that the core inventory tracking and multi-location management features are thoroughly validated, meeting the acceptance criteria and delivering high-quality functionality. After executing the tests, I will compile the results and any defects found for review during the sprint review meeting.
# UI/UX Designer Deliverables: ### Wireframes and Design Prototypes for Sprint 1
#
# #### Overview
# The following wireframes and design prototypes are created to address the user stories outlined in the sprint backlog. The focus is on usability and accessibility, ensuring that all users can effectively interact with the inventory tracking and multi-location management features.
#
# ---
#
# ### User Story 1: Inventory Tracking
#
# #### Wireframe 1: Inventory Dashboard
# - **Components**:
#   - **Header**: Logo, Navigation Menu (Home, Inventory, Locations, Reports)
#   - **Main Section**:
#     - **Current Inventory Levels**: A table displaying:
#       - Item Name
#       - Current Stock Level
#       - Reorder Level
#       - Status (In Stock, Low Stock, Out of Stock)
#     - **Alert System**: A notification banner at the top indicating low stock items.
#   - **Footer**: Contact information, Help, Terms of Service
#
# ![Inventory Dashboard Wireframe](https://via.placeholder.com/800x600?text=Inventory+Dashboard+Wireframe)
#
# #### Design Prototype: Inventory Dashboard
# - **Color Scheme**: Soft blues and greens for a calming effect, with red for low stock alerts.
# - **Typography**: Clear, sans-serif font for readability.
# - **Accessibility Features**:
#   - High contrast text for visibility.
#   - Alt text for images and icons.
#   - Keyboard navigable elements.
#
# ---
#
# ### User Story 2: Multi-location Management
#
# #### Wireframe 2: Multi-location Inventory View
# - **Components**:
#   - **Header**: Same as Inventory Dashboard
#   - **Main Section**:
#     - **Location Selector**: Dropdown to select a location.
#     - **Stock Levels by Location**: A table displaying:
#       - Location Name
#       - Item Name
#       - Stock Level
#       - Transfer Button (to initiate stock transfer)
#     - **Transfer Stock Modal**: A pop-up modal for transferring stock between locations.
#   - **Footer**: Same as Inventory Dashboard
#
# ![Multi-location Inventory View Wireframe](https://via.placeholder.com/800x600?text=Multi-location+Inventory+View+Wireframe)
#
# #### Design Prototype: Multi-location Inventory View
# - **Color Scheme**: Consistent with the Inventory Dashboard.
# - **Typography**: Consistent with the Inventory Dashboard.
# - **Accessibility Features**:
#   - Clear labels for dropdowns and buttons.
#   - Focus indicators for keyboard navigation.
#   - Responsive design for mobile and tablet views.
#
# ---
#
# ### Additional Considerations
#
# #### Usability Testing
# - Conduct usability testing sessions with real users to gather feedback on the wireframes and prototypes.
# - Focus on the ease of navigation, clarity of information, and overall user satisfaction.
#
# #### Accessibility Compliance
# - Ensure compliance with WCAG 2.1 guidelines.
# - Include features such as screen reader compatibility, keyboard navigation, and color contrast checks.
#
# #### Feedback Loop
# - After the sprint review, gather feedback from stakeholders and users to iterate on the designs.
# - Use feedback to refine the wireframes and prototypes for future sprints.
#
# ---
#
# ### Conclusion
# The wireframes and design prototypes created for Sprint 1 focus on delivering a user-friendly and accessible experience for inventory tracking and multi-location management. By prioritizing usability and accessibility, we aim to ensure that all users can effectively manage their inventory across multiple locations.
# Business Analyst Deliverables: ### Refined User Stories for Sprint 1
#
# #### User Story 1: Inventory Tracking
# **As a** warehouse manager,
# **I want** to track current inventory levels in real-time,
# **So that** I can manage stock efficiently and avoid stockouts.
#
# **Requirements:**
# 1. **Database Schema Design**:
#    - Create a table for inventory items with fields: `item_id`, `item_name`, `quantity`, `location_id`, `threshold_level`, `last_updated`.
#    - Create a table for locations with fields: `location_id`, `location_name`, `address`.
#
# 2. **API Development**:
#    - Develop a RESTful API endpoint `/api/inventory/current` that returns the current inventory levels for all items.
#    - The API should support filtering by `location_id`.
#
# 3. **Front-end Display**:
#    - Implement a dashboard that displays current inventory levels in a tabular format.
#    - Include columns for `item_name`, `quantity`, `location`, and `alert status` (indicating if the stock is below the threshold).
#
# 4. **Alert System**:
#    - Create a notification system that triggers alerts when inventory levels fall below the `threshold_level`.
#    - Alerts should be displayed on the dashboard and sent via email to the warehouse manager.
#
# **Acceptance Criteria:**
# - The database schema is approved and implemented.
# - The API returns accurate current inventory levels for all items.
# - The front-end dashboard displays inventory levels correctly.
# - Alerts are triggered and displayed for items below the threshold level.
# - Email notifications are sent to the warehouse manager for low stock items.
#
# ---
#
# #### User Story 2: Multi-location Management
# **As a** warehouse manager,
# **I want** to manage inventory across multiple locations,
# **So that** I can ensure optimal stock levels at each site.
#
# **Requirements:**
# 1. **Database Schema Design**:
#    - Extend the existing inventory table to include `location_id` to associate items with specific locations.
#    - Ensure the locations table is linked to the inventory table.
#
# 2. **API Development**:
#    - Develop a RESTful API endpoint `/api/inventory/locations` that returns stock levels for each location.
#    - The API should support filtering by `location_id` and return a summary of stock levels.
#
# 3. **Front-end Interface**:
#    - Implement a user interface that allows users to select a location and view stock levels for that location.
#    - Include functionality to display stock levels in a graphical format (e.g., bar chart).
#
# 4. **Stock Transfer Functionality**:
#    - Create a feature that allows users to transfer stock between locations.
#    - Implement a form that captures `item_id`, `source_location`, `destination_location`, and `quantity`.
#    - Ensure that the transfer updates the inventory levels in real-time.
#
# **Acceptance Criteria:**
# - The database schema for multi-location management is approved and implemented.
# - The API returns accurate stock levels for each location.
# - The front-end interface allows users to view stock levels by location.
# - The stock transfer functionality works correctly, updating inventory levels in real-time.
# - Users receive confirmation notifications upon successful stock transfers.
#
# ---
#
# ### Requirements Document
#
# #### Overview
# This document outlines the requirements for implementing core inventory tracking and multi-location management features in the inventory management system.
#
# #### Functional Requirements
# 1. **Inventory Tracking**:
#    - Real-time tracking of inventory levels.
#    - Alert system for low stock levels.
#    - User-friendly dashboard for inventory visibility.
#
# 2. **Multi-location Management**:
#    - Ability to view stock levels by location.
#    - Functionality to transfer stock between locations.
#
# #### Non-Functional Requirements
# - The system should be responsive and load data within 2 seconds.
# - The API should handle up to 100 concurrent requests.
# - The alert system should send notifications within 5 minutes of stock level changes.
#
# #### User Interface Requirements
# - The dashboard should be intuitive and easy to navigate.
# - The stock transfer form should have validation to prevent negative stock levels.
#
# #### Security Requirements
# - User authentication must be implemented to restrict access to inventory management features.
# - Data encryption should be used for sensitive information.
#
# #### Testing Requirements
# - Test cases must be created for all functional requirements.
# - Performance testing should be conducted to ensure the system meets non-functional requirements.
#
# ### Conclusion
# The refined user stories and requirements document provide a clear roadmap for the development team to implement the core features of inventory tracking and multi-location management. The acceptance criteria will guide the QA team in validating the functionality before the end of Sprint 1.
# DevOps Engineer Deliverables: To set up a CI/CD pipeline for Sprint 1 based on the provided sprint backlog, we will create a deployment plan and pipeline configuration. This will ensure that the core inventory tracking and multi-location management features are delivered efficiently and reliably.
#
# ### Deployment Plan
#
# #### 1. **Environment Setup**
#    - **Development Environment**: Local development setup for developers to work on features.
#    - **Staging Environment**: A pre-production environment for testing and QA.
#    - **Production Environment**: The live environment where the application will be deployed.
#
# #### 2. **Database Setup**
#    - **Database Schema Design**:
#      - Create tables for inventory tracking and multi-location management.
#      - Use migrations to manage schema changes.
#    - **Database Management System**: Choose a suitable DBMS (e.g., PostgreSQL, MySQL).
#
# #### 3. **Deployment Strategy**
#    - **Continuous Integration**: Automatically build and test the application on every commit.
#    - **Continuous Deployment**: Deploy to the staging environment after successful builds and tests. Manual approval for production deployment.
#
# #### 4. **Rollback Plan**
#    - Maintain previous versions of the application in case of deployment failures.
#    - Use database backups to restore previous states if necessary.
#
# #### 5. **Monitoring and Alerts**
#    - Set up monitoring for application performance and error tracking.
#    - Implement alerts for low stock levels in the inventory system.
#
# ### Pipeline Configuration
#
# #### 1. **CI/CD Tool Selection**
#    - Use a CI/CD tool like Jenkins, GitHub Actions, or GitLab CI.
#
# #### 2. **Pipeline Stages**
#    - **Build Stage**:
#      - Compile the application.
#      - Run unit tests.
#    - **Test Stage**:
#      - Run integration tests.
#      - Execute end-to-end tests.
#    - **Deploy Stage**:
#      - Deploy to the staging environment.
#      - Run smoke tests to verify deployment.
#    - **Approval Stage** (for production):
#      - Manual approval required to deploy to production.
#    - **Production Deployment**:
#      - Deploy the application to the production environment.
#
# #### 3. **Sample Pipeline Configuration (Using GitHub Actions)**
#
# ```yaml
# name: CI/CD Pipeline
#
# on:
#   push:
#     branches:
#       - main
#
# jobs:
#   build:
#     runs-on: ubuntu-latest
#     steps:
#       - name: Checkout code
#         uses: actions/checkout@v2
#
#       - name: Set up Node.js
#         uses: actions/setup-node@v2
#         with:
#           node-version: '14'
#
#       - name: Install dependencies
#         run: npm install
#
#       - name: Run unit tests
#         run: npm test
#
#   test:
#     runs-on: ubuntu-latest
#     needs: build
#     steps:
#       - name: Checkout code
#         uses: actions/checkout@v2
#
#       - name: Run integration tests
#         run: npm run test:integration
#
#   deploy-staging:
#     runs-on: ubuntu-latest
#     needs: test
#     steps:
#       - name: Checkout code
#         uses: actions/checkout@v2
#
#       - name: Deploy to Staging
#         run: |
#           echo "Deploying to Staging Environment"
#           # Add deployment commands here (e.g., using AWS CLI, Heroku CLI, etc.)
#
#   approve-production:
#     runs-on: ubuntu-latest
#     needs: deploy-staging
#     steps:
#       - name: Request approval
#         run: echo "Waiting for approval to deploy to production..."
#
#   deploy-production:
#     runs-on: ubuntu-latest
#     needs: approve-production
#     steps:
#       - name: Checkout code
#         uses: actions/checkout@v2
#
#       - name: Deploy to Production
#         run: |
#           echo "Deploying to Production Environment"
#           # Add deployment commands here (e.g., using AWS CLI, Heroku CLI, etc.)
# ```
#
# ### Conclusion
#
# This deployment plan and pipeline configuration will facilitate the continuous integration and deployment of the inventory tracking and multi-location management features. The team should ensure that all tasks are completed within the sprint duration, and the CI/CD pipeline should be tested to confirm that it works as expected before the end of Sprint 1. Regular communication and collaboration among team members will be essential to address any blockers and ensure a successful sprint delivery.
# Architect Deliverables: ### System Architecture for Sprint 1
#
# #### Architecture Diagram
#
# Below is a high-level architecture diagram for the inventory tracking and multi-location management features:
#
# ```
# +---------------------+
# |   User Interface    |
# | (Web/Mobile App)    |
# +---------------------+
#           |
#           v
# +---------------------+
# |      API Layer      |
# | (RESTful Services)  |
# +---------------------+
#           |
#           v
# +---------------------+
# |   Business Logic    |
# | (Service Layer)     |
# +---------------------+
#           |
#           v
# +---------------------+
# |   Database Layer    |
# | (PostgreSQL/MySQL)  |
# +---------------------+
#           |
#           v
# +---------------------+
# |   Notification      |
# |     Service         |
# | (Email/SMS Alerts)  |
# +---------------------+
# ```
#
# #### Technical Specifications
#
# 1. **User Interface (UI)**
#    - **Technology Stack**: React.js or Angular for web; React Native or Flutter for mobile.
#    - **Features**:
#      - Display current inventory levels.
#      - Show stock levels by location.
#      - Alert notifications for low stock levels.
#
# 2. **API Layer**
#    - **Technology Stack**: Node.js with Express.js or Python with Flask/Django.
#    - **Endpoints**:
#      - `GET /api/inventory`: Fetch current inventory levels.
#      - `GET /api/inventory/location/:locationId`: Fetch stock levels for a specific location.
#      - `POST /api/inventory/transfer`: Transfer stock between locations.
#      - `POST /api/inventory/alert`: Trigger alert for low stock levels.
#    - **Authentication**: JWT (JSON Web Tokens) for secure access.
#
# 3. **Business Logic Layer**
#    - **Service Implementation**:
#      - InventoryService: Handles inventory tracking logic.
#      - LocationService: Manages multi-location operations.
#      - NotificationService: Sends alerts for low stock levels.
#    - **Scalability Considerations**:
#      - Use microservices architecture to separate inventory and location management services.
#      - Implement caching (e.g., Redis) for frequently accessed data to reduce database load.
#
# 4. **Database Layer**
#    - **Database**: PostgreSQL or MySQL.
#    - **Schema Design**:
#      - **Inventory Table**:
#        - `id`: Primary Key
#        - `product_id`: Foreign Key
#        - `location_id`: Foreign Key
#        - `quantity`: Integer
#        - `last_updated`: Timestamp
#      - **Location Table**:
#        - `id`: Primary Key
#        - `name`: String
#        - `address`: String
#      - **Product Table**:
#        - `id`: Primary Key
#        - `name`: String
#        - `description`: String
#    - **Indexes**: Create indexes on `location_id` and `product_id` for faster queries.
#
# 5. **Notification Service**
#    - **Technology Stack**: Use a service like Twilio for SMS or SendGrid for email notifications.
#    - **Functionality**:
#      - Trigger alerts when inventory levels fall below a defined threshold.
#      - Allow configuration of alert thresholds per product/location.
#
# #### Scalability Considerations
# - **Load Balancing**: Use a load balancer (e.g., Nginx or AWS ELB) to distribute incoming API requests across multiple instances of the API layer.
# - **Database Sharding**: As the number of locations and products grows, consider sharding the database to improve performance.
# - **Microservices**: Each feature (inventory tracking, multi-location management) can be developed as a separate microservice, allowing independent scaling and deployment.
#
# #### Conclusion
# This architecture is designed to support the core features of inventory tracking and multi-location management while ensuring scalability and maintainability. The use of modern technologies and best practices will facilitate a robust implementation that can grow with the needs of the business.
# Security Engineer Deliverables: ### Security Report for Sprint 1
#
# #### Overview
# The implementation of core inventory tracking and multi-location management features introduces several potential security vulnerabilities that need to be addressed to ensure the integrity, confidentiality, and availability of the inventory data. This report outlines identified vulnerabilities based on the sprint backlog and provides recommendations for mitigation.
#
# #### Identified Vulnerabilities
#
# 1. **Database Schema Design Vulnerabilities**
#    - **Risk**: Poorly designed database schemas can lead to SQL injection attacks, data leakage, and unauthorized access to sensitive information.
#    - **Recommendation**:
#      - Use parameterized queries or prepared statements to prevent SQL injection.
#      - Implement proper access controls to restrict database access based on user roles.
#
# 2. **API Security Vulnerabilities**
#    - **Risk**: APIs that fetch inventory levels and manage stock transfers may be susceptible to unauthorized access, data manipulation, and denial of service attacks.
#    - **Recommendation**:
#      - Implement authentication and authorization mechanisms (e.g., OAuth 2.0, JWT) to secure API endpoints.
#      - Rate limit API requests to prevent abuse and denial of service attacks.
#      - Validate and sanitize all input data to prevent injection attacks.
#
# 3. **Front-end Security Vulnerabilities**
#    - **Risk**: The front-end display for inventory levels may be vulnerable to Cross-Site Scripting (XSS) attacks, which can compromise user sessions and data.
#    - **Recommendation**:
#      - Use Content Security Policy (CSP) to mitigate XSS risks.
#      - Sanitize and escape user inputs before rendering them on the front-end.
#
# 4. **Alert System Vulnerabilities**
#    - **Risk**: The alert system for low stock levels may be exploited to trigger false alerts or spam notifications.
#    - **Recommendation**:
#      - Implement validation checks to ensure alerts are generated based on legitimate criteria.
#      - Use secure channels (e.g., HTTPS, secure email) for sending alerts to prevent interception.
#
# 5. **Data Transfer Vulnerabilities**
#    - **Risk**: Transferring stock between locations may expose sensitive data if not properly secured.
#    - **Recommendation**:
#      - Ensure that all data transfers are encrypted using TLS/SSL.
#      - Implement logging and monitoring to track stock transfer activities for auditing purposes.
#
# #### Mitigation Plan
#
# 1. **Database Security**
#    - Conduct a security review of the database schema design.
#    - Implement parameterized queries and access controls.
#
# 2. **API Security**
#    - Integrate authentication and authorization mechanisms for all API endpoints.
#    - Implement input validation and output encoding for all API interactions.
#    - Set up rate limiting for API requests.
#
# 3. **Front-end Security**
#    - Implement CSP and sanitize user inputs.
#    - Conduct regular security testing (e.g., penetration testing) on the front-end application.
#
# 4. **Alert System Security**
#    - Review and validate alert generation logic.
#    - Use secure communication methods for alert notifications.
#
# 5. **Data Transfer Security**
#    - Ensure all data transfers are encrypted.
#    - Implement logging and monitoring for stock transfer activities.
#
# ### Conclusion
# The successful implementation of the inventory tracking and multi-location management features requires a proactive approach to security. By addressing the identified vulnerabilities and following the recommended mitigation strategies, the team can enhance the security posture of the application and protect sensitive inventory data. Regular security audits and testing should be integrated into future sprints to ensure ongoing security compliance and risk management.
# Technical Writer Deliverables: # Sprint 1 Deliverables Documentation
#
# ## 1. Documentation
#
# ### User Guides
#
# #### Inventory Tracking User Guide
#
# **Overview**: This guide provides instructions on how to use the inventory tracking feature.
#
# **Features**:
# - **Viewing Current Inventory Levels**: Users can access the inventory dashboard to view real-time stock levels.
# - **Low Stock Alerts**: Users will receive notifications when stock levels fall below a predefined threshold.
#
# **Instructions**:
# 1. Navigate to the Inventory Dashboard.
# 2. View the current stock levels displayed for each item.
# 3. Set up low stock alerts by specifying the threshold for each item in the settings.
#
# #### Multi-location Management User Guide
#
# **Overview**: This guide explains how to manage inventory across multiple locations.
#
# **Features**:
# - **Viewing Stock Levels by Location**: Users can select different locations to view specific stock levels.
# - **Transferring Stock**: Users can transfer stock between locations seamlessly.
#
# **Instructions**:
# 1. Go to the Multi-location Management section.
# 2. Select a location from the dropdown menu to view stock levels.
# 3. To transfer stock, select the item, specify the quantity, and choose the destination location.
#
# ### API Documentation
#
# #### Inventory Tracking API
#
# - **GET /api/inventory**: Fetch current inventory levels.
# - **POST /api/inventory/alerts**: Set up low stock alerts.
#
# #### Multi-location Management API
#
# - **GET /api/locations/{locationId}/inventory**: Fetch stock levels for a specific location.
# - **POST /api/locations/transfer**: Transfer stock between locations.
#
# ## 2. Release Summary
#
# ### Sprint 1 Release Notes
#
# **Release Version**: 1.0
# **Release Date**: [Insert Date]
#
# **New Features**:
# - **Inventory Tracking**:
#   - Real-time visibility of inventory levels.
#   - Alert system for low stock levels.
#
# - **Multi-location Management**:
#   - View stock levels by location.
#   - Functionality to transfer stock between locations.
#
# **Improvements**:
# - Enhanced user interface for better navigation and usability.
#
# **Bug Fixes**:
# - Resolved minor UI issues related to inventory display.
#
# **Known Issues**:
# - Integration with legacy systems may require further testing in future sprints.
#
# ## 3. Final Report After Sprint 1
#
# ### Sprint 1 Summary
#
# **Sprint Duration**: 2 weeks
# **Total Story Points Completed**: 16
#
# **Achievements**:
# - Successfully implemented core inventory tracking and multi-location management features.
# - Completed all user stories as planned, with features ready for demonstration.
#
# **Team Performance**:
# - The team collaborated effectively, with daily stand-ups facilitating communication.
# - Blockers were addressed promptly, and the design review meeting helped streamline the database schema approval process.
#
# **Feedback and Retrospective**:
# - Stakeholders expressed satisfaction with the new features and their usability.
# - The team identified areas for improvement, including more thorough testing of integration points and better documentation practices.
#
# **Next Steps**:
# - Prepare for Sprint 2, focusing on enhancements based on feedback and addressing known issues.
# - Continue to refine documentation and user guides based on user feedback.
#
# This structured documentation and reporting will serve as a foundation for future sprints, ensuring clarity and continuity in the development process.
# Customer Feedback (Sprint 1): ### Feedback on Sprint 1 Deliverables
#
# #### General Observations
# Overall, the deliverables for Sprint 1 demonstrate a solid foundation for the Retail Inventory Management System. The team has successfully implemented core features related to inventory tracking and multi-location management, and the documentation is comprehensive. Here are some specific feedback points across various areas:
#
# #### Developer Deliverables
# 1. **Database Schema Design**:
#    - The schema design is well-structured, but consider adding indexes on frequently queried fields (e.g., `location_id`, `product_id`) to improve query performance.
#    - Ensure that the `Alerts` table has a mechanism to handle multiple alerts for the same product, if necessary.
#
# 2. **API Development**:
#    - The API endpoints are clearly defined and follow RESTful principles. However, consider adding pagination for the inventory fetch endpoints to handle large datasets efficiently.
#    - Implement error handling for API responses to provide meaningful messages in case of failures.
#
# 3. **Front-end Display**:
#    - The front-end implementation is straightforward and functional. Consider enhancing the user experience by adding loading indicators while fetching data and error messages for failed API calls.
#    - Ensure that the front-end is responsive and works well on various devices.
#
# 4. **Alert System**:
#    - The alert system is a great addition. Consider implementing a more robust notification system that allows users to customize alert preferences (e.g., email, SMS).
#
# #### QA Engineer Deliverables
# 1. **Test Case Development**:
#    - The test cases are well-structured and cover essential functionalities. Ensure that edge cases are also considered, such as testing with zero stock or invalid location IDs.
#    - Include performance testing cases to validate the system's response under load, especially for the API endpoints.
#
# 2. **Test Execution and Reporting**:
#    - The test results template is clear. Ensure that actual results are documented during testing to track discrepancies and facilitate debugging.
#
# #### UI/UX Designer Deliverables
# 1. **Wireframes and Design Prototypes**:
#    - The wireframes are user-friendly and visually appealing. Consider conducting usability testing with real users to gather feedback on the design and make iterative improvements.
#    - Ensure that accessibility features are thoroughly tested to comply with WCAG guidelines.
#
# #### Business Analyst Deliverables
# 1. **Refined User Stories**:
#    - The user stories are well-defined and include clear acceptance criteria. Ensure that all stakeholders are aligned on these criteria to avoid scope creep.
#    - Consider adding user personas to the user stories to better understand the target audience and their needs.
#
# #### DevOps Engineer Deliverables
# 1. **Deployment Plan**:
#    - The deployment plan is comprehensive. Ensure that rollback procedures are tested during deployment to minimize downtime in case of issues.
#    - Consider implementing automated testing in the CI/CD pipeline to catch issues early in the development process.
#
# #### Architect Deliverables
# 1. **System Architecture**:
#    - The architecture diagram is clear and provides a good overview of the system components. Consider documenting the data flow between components for better clarity.
#    - Ensure that the architecture supports scalability and maintainability as the system grows.
#
# #### Security Engineer Deliverables
# 1. **Security Report**:
# ...
#
# 3. **Reporting Service**
#    - **Technology Stack:** Node.js with Express.js.
#    - **Features:**
#      - Generates reports based on sales trends and inventory data.
#      - Allows customization of reports by date range and product category.
#      - Utilizes libraries like Chart.js or D3.js for visual representation of data.
#
# 4. **Database**
#    - **Technology Stack:** PostgreSQL or MongoDB.
#    - **Features:**
#      - Stores sales data, inventory data, and user-generated reports.
#      - Optimized for read-heavy operations to support report generation.
#
# 5. **Barcode Service**
#    - **Technology Stack:** Node.js with Express.js.
#    - **Features:**
#      - Integrates with barcode scanning libraries (e.g., QuaggaJS for web).
#      - Handles adding and removing items from inventory based on scanned barcodes.
#      - Updates inventory levels in real-time.
#
# 6. **Inventory Database**
#    - **Technology Stack:** PostgreSQL or MongoDB.
#    - **Features:**
#      - Dedicated database for inventory management.
#      - Ensures data integrity and supports transactions for inventory updates.
#
# 7. **Security**
#    - **Authentication:** OAuth 2.0 for secure API access.
#    - **Data Encryption:** TLS for data in transit and AES for data at rest.
#
# 8. **Scalability Considerations**
#    - **Microservices Architecture:** Each service can be scaled independently based on load.
#    - **Load Balancing:** Use of load balancers to distribute incoming traffic across multiple instances of services.
#    - **Database Sharding:** For large datasets, consider sharding the database to improve performance.
#
# 9. **Testing and Quality Assurance**
#    - **Unit Testing:** Implement unit tests for each microservice.
#    - **Integration Testing:** Ensure that services communicate correctly.
#    - **Performance Testing:** Load testing to ensure the system can handle expected traffic.
#
# ### Conclusion
# This architecture is designed to support the development of Reporting and Analytics features and Barcode Scanning Support while ensuring scalability and maintainability. The use of microservices allows for independent development and deployment, facilitating a more agile development process. The architecture also considers future growth and potential integration with other systems.
# Security Engineer Deliverables: ### Security Audit Report for Sprint 3 Deliverables
#
# #### Overview
# This security audit report evaluates the deliverables from Sprint 3, focusing on the Reporting and Analytics features and the Barcode Scanning Support. The goal is to identify potential vulnerabilities and recommend mitigations to enhance the security posture of the application.
#
# #### Identified Vulnerabilities
#
# 1. **Reporting and Analytics Features**
#    - **Data Exposure Risk:** Customizable reports may expose sensitive sales data if not properly secured.
#    - **Injection Attacks:** The report generation functionality could be vulnerable to SQL injection if user inputs are not sanitized.
#    - **Access Control Issues:** Users may gain unauthorized access to reports if proper access controls are not implemented.
#
# 2. **Barcode Scanning Support**
#    - **Input Validation:** The barcode scanning feature may be susceptible to malformed input, leading to potential buffer overflow or injection attacks.
#    - **Data Integrity Risks:** If the barcode scanning updates inventory levels without proper validation, it could lead to incorrect inventory records.
#    - **Hardware Security:** The use of external barcode scanning hardware may introduce vulnerabilities if not properly secured.
#
# #### Recommendations for Mitigations
#
# 1. **For Reporting and Analytics Features**
#    - **Implement Role-Based Access Control (RBAC):** Ensure that only authorized users can access sensitive reports. Define user roles and permissions clearly.
#    - **Input Validation and Sanitization:** Use parameterized queries or prepared statements to prevent SQL injection. Validate and sanitize all user inputs before processing.
#    - **Data Encryption:** Encrypt sensitive data both at rest and in transit to protect against unauthorized access.
#
# 2. **For Barcode Scanning Support**
#    - **Input Validation:** Implement strict validation rules for barcode inputs to prevent malformed data from being processed. Use whitelisting techniques to allow only valid barcode formats.
#    - **Transaction Logging:** Maintain logs of all inventory changes made through barcode scanning to ensure traceability and accountability.
#    - **Secure Hardware Integration:** Ensure that any external barcode scanning devices are securely configured and regularly updated to mitigate risks associated with hardware vulnerabilities.
#
# 3. **General Security Practices**
#    - **Conduct Security Testing:** Perform regular security testing, including penetration testing and vulnerability assessments, to identify and remediate potential security issues.
#    - **User Training:** Provide training for users on security best practices, including recognizing phishing attempts and securing sensitive data.
#    - **Incident Response Plan:** Develop and maintain an incident response plan to address potential security breaches effectively.
#
# ### Mitigation Plan
#
# | Vulnerability | Recommended Mitigation | Responsible Team Member | Timeline |
# |---------------|------------------------|-------------------------|----------|
# | Data Exposure Risk | Implement RBAC and data encryption | [Team Member Name] | By End of Sprint 4 |
# | Injection Attacks | Use parameterized queries and input validation | [Team Member Name] | By End of Sprint 4 |
# | Access Control Issues | Define user roles and permissions | [Team Member Name] | By End of Sprint 4 |
# | Input Validation | Implement strict validation rules for barcode inputs | [Team Member Name] | By End of Sprint 4 |
# | Data Integrity Risks | Maintain transaction logs for inventory changes | [Team Member Name] | By End of Sprint 4 |
# | Hardware Security | Securely configure external barcode scanning devices | [Team Member Name] | By End of Sprint 4 |
#
# ### Conclusion
# The deliverables from Sprint 3 present several potential security vulnerabilities that need to be addressed to ensure the integrity and confidentiality of the application. By implementing the recommended mitigations, the team can significantly reduce the risk of security incidents and enhance the overall security posture of the application. Regular reviews and updates to the security measures will be essential as the application evolves.
# Technical Writer Deliverables: # Sprint 3 Documentation
#
# ## Sprint Summary
#
# **Sprint 3 Summary:**
# - **Start Date:** [Insert Start Date]
# - **End Date:** [Insert End Date]
# - **Total User Stories Selected:** 2
# - **Total Tasks:** [Insert Total Number of Tasks]
# - **Team Members:** [List Team Members]
#
# ### Key Achievements:
# - **Reporting and Analytics Features:**
#   - Developed report templates for sales analysis.
#   - Implemented functionality to generate reports based on sales trends.
#   - Enabled customization of reports by date range and product category.
#   - Conducted thorough testing to ensure data accuracy in report generation.
#
# - **Barcode Scanning Support:**
#   - Researched and selected appropriate barcode scanning technology.
#   - Developed features for adding and removing items from inventory using barcode scanning.
#   - Tested the barcode scanning feature for accuracy and efficiency, ensuring automatic updates to inventory levels.
#
# ### Next Steps:
# - Prepare for the Sprint Review to showcase the completed features.
# - Gather feedback from stakeholders to refine future user stories.
# - Plan for Sprint 4, focusing on User Access and Permissions, User-Friendly Interface, and Data Backup and Security measures.
#
# ## User Guides
#
# ### User Guide for Reporting and Analytics Features
#
# #### Overview
# This guide provides instructions on how to utilize the Reporting and Analytics features to generate customizable sales reports.
#
# #### Generating Reports
# 1. **Access the Reporting Module:**
#    - Navigate to the Reporting section in the main menu.
#
# 2. **Select Report Type:**
#    - Choose the type of report you wish to generate (e.g., Sales Trends, Inventory Turnover).
#
# 3. **Customize Report:**
#    - Set the desired date range.
#    - Select product categories to filter the report.
#
# 4. **Generate Report:**
#    - Click on the "Generate" button to create the report.
#    - Review the report for accuracy.
#
# 5. **Export Options:**
#    - Reports can be exported in various formats (PDF, Excel).
#
# #### Troubleshooting
# - If the report does not generate, check for any filters that may be too restrictive.
# - Ensure that the data source is connected and accessible.
#
# ### User Guide for Barcode Scanning Support
#
# #### Overview
# This guide explains how to use the barcode scanning feature for efficient inventory management.
#
# #### Adding Items to Inventory
# 1. **Access the Inventory Module:**
#    - Go to the Inventory section in the main menu.
#
# 2. **Select Add Item:**
#    - Click on the "Add Item" button.
#
# 3. **Scan Barcode:**
#    - Use the barcode scanner to scan the item’s barcode.
#    - The system will automatically populate item details.
#
# 4. **Confirm Addition:**
#    - Review the item details and click "Confirm" to add the item to inventory.
#
# #### Removing Items from Inventory
# 1. **Access the Inventory Module:**
#    - Navigate to the Inventory section.
#
# 2. **Select Remove Item:**
#    - Click on the "Remove Item" button.
#
# 3. **Scan Barcode:**
#    - Scan the barcode of the item you wish to remove.
#    - The system will display the item details.
#
# 4. **Confirm Removal:**
#    - Click "Confirm" to remove the item from inventory.
#
# #### Troubleshooting
# - Ensure the barcode scanner is properly connected and configured.
# - If the item does not scan, check the barcode for damage or clarity.
#
# ## Release Notes
#
# ### Release Notes for Sprint 3
#
# **Release Version:** 3.0
# **Release Date:** [Insert Release Date]
#
# #### New Features:
# - **Reporting and Analytics:**
#   - Users can now generate customizable reports based on sales trends and inventory performance.
#   - Reports can be filtered by date range and product category.
#
# - **Barcode Scanning Support:**
#   - Added functionality for adding and removing items from inventory using barcode scanning.
#   - Inventory levels are updated automatically upon scanning.
#
# #### Bug Fixes:
# - Resolved issues related to report generation delays.
# - Fixed bugs in the barcode scanning feature that affected item recognition.
#
# #### Known Issues:
# - Some users may experience delays in report generation during peak usage times.
# - Ongoing improvements to barcode scanning accuracy are being implemented.
#
# ## Final Report After Three Sprints
#
# ### Final Report Summary
#
# **Total Sprints Completed:** 3
# **Overall Goals Achieved:**
# - Successfully developed and implemented key features including User Management, Inventory Management, and Reporting & Analytics.
# - Enhanced user experience through the introduction of barcode scanning for inventory management.
#
# ### Key Deliverables:
# - Comprehensive user guides for each feature developed.
# - Detailed release notes summarizing new features, bug fixes, and known issues.
# - Continuous feedback loop established with stakeholders to refine future development.
#
# ### Recommendations for Future Sprints:
# - Focus on enhancing user access and permissions for better security.
# - Improve user interface for a more intuitive experience.
# - Implement data backup and security measures to protect user data.
#
# This structured documentation provides a clear overview of the deliverables from Sprint 3, ensuring that all stakeholders are informed and equipped to utilize the new features effectively.
# Customer Feedback (Sprint 3): ### Feedback on Sprint 3 Deliverables
#
# #### General Observations
# Overall, the deliverables for Sprint 3 demonstrate a strong alignment with the requirements outlined for the Retail Inventory Management System. The implementation of Reporting and Analytics features, along with Barcode Scanning Support, is well-structured and addresses key user needs. The documentation is comprehensive, providing clear user guides and release notes that will aid in user adoption and understanding.
#
# #### Specific Feedback
#
# 1. **Reporting and Analytics**
#    - **Implementation:**
#      - The report generation functionality is well-structured, with clear methods for filtering data based on date range and product category. However, ensure that the filtering logic is thoroughly tested to handle edge cases (e.g., no sales data for the selected range).
#    - **Testing:**
#      - The test cases are well-defined, covering essential scenarios. Consider adding tests for edge cases, such as generating reports with no data or invalid date ranges.
#    - **User Interface:**
#      - The wireframes for the report dashboard and customization options are intuitive. Ensure that the final design maintains a consistent look and feel with the rest of the application.
#
# 2. **Barcode Scanning Support**
#    - **Implementation:**
#      - The barcode scanning features for adding and removing items are implemented effectively. Ensure that the system can handle various barcode formats and that error handling is robust for invalid scans.
#    - **Testing:**
#      - The test cases for barcode scanning are comprehensive. It would be beneficial to include tests for scenarios where the barcode is not recognized or when attempting to remove more items than available.
#    - **User Interface:**
#      - The wireframes for the inventory management interface are user-friendly. Consider adding visual feedback (e.g., animations or alerts) when items are successfully added or removed to enhance user experience.
#
# 3. **Security Considerations**
#    - The security audit report identifies critical vulnerabilities and provides actionable recommendations. Ensure that the team prioritizes implementing these mitigations, especially around input validation and access control.
#    - Consider conducting a security review after implementing the recommendations to ensure that all potential vulnerabilities are addressed.
#
# 4. **Documentation**
#    - The user guides are clear and provide step-by-step instructions, which will be helpful for end-users. Ensure that the guides are easily accessible within the application.
#    - The release notes are well-structured, but consider including a section for user feedback or a link to a feedback form to gather insights on the new features.
#
# 5. **CI/CD Pipeline**
#    - The CI/CD pipeline configuration is well thought out, with clear stages for building, testing, and deploying the application. Ensure that the deployment commands are thoroughly tested in a staging environment before moving to production.
#    - Consider adding automated tests in the pipeline to catch issues early in the development process.
#
# 6. **Next Steps**
#    - The next steps outlined are appropriate and align with the goals for Sprint 4. Ensure that the team remains focused on gathering feedback from stakeholders to refine future user stories and prioritize enhancements based on user needs.
#
# ### Conclusion
# The deliverables for Sprint 3 are on track and demonstrate a solid understanding of the requirements for the Retail Inventory Management System. By addressing the feedback provided, the team can enhance the quality and usability of the features developed. Continue to foster collaboration and communication among team members to ensure a successful Sprint 4.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 35
#      32     return state
#      34 # Run the workflow
# ---> 35 final_state = run_workflow()
#
# Cell In[29], line 25, in run_workflow()
#      23 elif state["current_phase"] == "development":
#      24     state = development_phase(state)
# ---> 25 elif state["current_phase"] == "customer_review":
#      26     state = customer_review_phase(state)
#      27 elif state["current_phase"] == "final_report":
#
# KeyboardInterrupt:

# %%
from langgraph.graph import StateGraph, END

# Initialize the graph
workflow = StateGraph(ScrumState)

# Add nodes
workflow.add_node("customer", customer_phase)
workflow.add_node("product_owner", product_owner_phase)
workflow.add_node("scrum_master", scrum_master_phase)
workflow.add_node("development", development_phase)
workflow.add_node("customer_review", customer_review_phase)

# Add edges
workflow.add_edge("customer", "product_owner")
workflow.add_edge("product_owner", "scrum_master")
workflow.add_edge("scrum_master", "development")
workflow.add_edge("development", "customer_review")

# Conditional edge for sprint iteration
def route_after_review(state: ScrumState) -> str:
    if state["sprint_number"] <= 3:
        return "product_owner"
    return END

workflow.add_conditional_edges("customer_review", route_after_review, {"product_owner": "product_owner", END: END})

# Set entry point
workflow.set_entry_point("customer")

# Compile the graph
graph = workflow.compile()

# Run the graph
final_state = graph.invoke(initial_state)

# %%
# Test query to verify the index
response = query_engine.query("What was the feedback for Sprint 1?")
print("Query Response:", response)
